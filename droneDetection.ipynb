# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/78.2 GB disk)

# %%
import os
print(len(os.listdir("/content/drive/MyDrive/drone_test/valid/images")))
# Out:
# 2120

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.8 MB 8.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 68.7 MB/s
# ...
#      |████████████████████████████████| 145 kB 61.0 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.1 MB/s
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=cccc61ee5a4f86b41dcecc3f7c8e795c9d3565026566e8be0e30198a3ba159dd
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...

# %%
# !pip install torch==1.8.1 torchvision==0.9.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 804.1 MB 2.7 kB/s
# ...
#      |████████████████████████████████| 17.4 MB 623 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# ...

# %%
# !python train.py --img 300 --batch -1 --epochs 100 --data drone.yaml --cache
# Out:
# wandb: Currently logged in as: 2022. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s.pt, cfg=, data=drone.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=-1, imgsz=300, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.8.1+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights ./runs/train/exp10/weights/best.pt --img 640 --conf 0.25  --data data/drone.yaml --source /content/drive/MyDrive/drone_test/test/images
# Out:
# detect: weights=['./runs/train/exp10/weights/best.pt'], source=/content/drive/MyDrive/drone_test/test/images, data=data/drone.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.8.1+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/1940 /content/drive/MyDrive/drone_test/test/images/0001.jpg: 384x640 Done. (0.010s)
# image 2/1940 /content/drive/MyDrive/drone_test/test/images/0002.jpg: 384x640 Done. (0.010s)
# image 3/1940 /content/drive/MyDrive/drone_test/test/images/0003.jpg: 384x640 Done. (0.010s)
# ...

# %%
path = './runs/detect/exp/'
test_image= "/content/drive/MyDrive/drone_test/test/images"

display.Image(filename='./runs/detect/exp7/0004.jpg', width=300)

# %%
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.11.0+cu113 CPU

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.11.0+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.4/107.7 GB disk)

# %%
#import shutil

#shutil.rmtree ("/content/yolov5/data/drone/train/images") 
#shutil.rmtree("/content/yolov5/data/drone/train/labels")

# %%
 shutil.rmtree("/content/yolov5/yolov5")

# %%
#file = os.listdir("/content/yolov5/data/drone/test/images")
#print(len(file))
# Out:
# 190

# %%
#%cd /content/yolov5/data/drone/test/images

#!unzip "/content/yolov5/images.zip"
# Out:
# /content/yolov5/data/drone/test/images
# Archive:  /content/yolov5/images.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/yolov5/images.zip or
#         /content/yolov5/images.zip.zip, and cannot find /content/yolov5/images.zip.ZIP, period.

# %%
#%cd /content/yolov5
# Out:
# [Errno 2] No such file or directory: '/content/yolov5'
# /content

# %%
#! python train.py --img 640 --batch -1 --epochs 50 --drone.yaml --cache
# Out:
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import os
path_image= '/content/yolov5/runs/detect/exp4/'
pathOut = '/content/drive/MyDrive/test.gif'
fps = 30
import cv2
frame_array = []
for path in os.listdir(path_image) : 
    print(path)
    #if (idx % 2 == 0) | (idx % 5 == 0) :
    #    continue
    img = cv2.imread(path)
    height, width, layers = img.shape
    size = (width,height)
    frame_array.append(img)
out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
for i in range(len(frame_array)):
    # writing to a image array
    out.write(frame_array[i])
out.release()
# Out:
# 1927.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-e7fa01384ad5> in <module>()
#      10     #if (idx % 2 == 0) | (idx % 5 == 0) :
#      11     #    continue
# ---> 12     img = cv2.imread(path)
#      13     height, width, layers = img.shape
#      14     size = (width,height)
#
# /content/yolov5/utils/general.py in imread(path, flags)
#     998
#     999 def imread(path, flags=cv2.IMREAD_COLOR):
# -> 1000     return cv2.imdecode(np.fromfile(path, np.uint8), flags)
#    1001
#    1002
#
# FileNotFoundError: [Errno 2] No such file or directory: '1927.jpg'
